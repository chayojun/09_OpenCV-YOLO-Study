# %% [markdown]
# # 1. 이미지 불러오기

# %%
from PIL import Image

image_path = "../images/starry_night.jpg"
image = Image.open(image_path)
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x640>

# %%
import cv2
import matplotlib.pyplot as plt

image_path = "../images/starry_night.jpg"
image_cv = cv2.imread(image_path)

# print(image_cv)
plt.imshow(image_cv)
plt.axis("off")
plt.show()

# %%
import numpy as np

print(np.array(image)[0][0]) # R G B
print(image_cv[0][0]) # B G R
# Out:
# [  6  22 109]
# [109  22   6]

# %%
image_cv2 = cv2.cvtColor(image_cv, cv2.COLOR_BGR2RGB)

plt.imshow(image_cv2)
plt.axis("off")
plt.show()

# %% [markdown]
# # 2. 이미지 정보 파악하기

# %%
print(type(image_cv2))
print(image_cv.shape) # (h: 높이, w, c)
print(image_cv.ndim)
print(image_cv.dtype)
print(image_cv.size)
# Out:
# <class 'numpy.ndarray'>
# (640, 1024, 3)
# 3
# uint8
# 1966080

# %% [markdown]
# # 3. 이미지 변환하기

# %%
image_cv3 = cv2.cvtColor(image_cv, cv2.COLOR_BGR2GRAY)

plt.imshow(image_cv3, cmap="gray")
plt.axis("off")
plt.show()

# %% [markdown]
# # 4. 이미지 저장하기

# %%
save_path = "../images/starry_night_gray.jpg"

cv2.imwrite(save_path, image_cv3)
# Out:
# True

# %% [markdown]
# # 5. 이미지 그리기

# %%
import cv2 
import numpy as np 
import matplotlib.pyplot as plt

# 이미지 만들기(h:높이, w:너비, c:채널), RGB 0~255 (255, 255, 255)
image = np.zeros((200,200,3), dtype=np.uint8) + 255 # 화이트 도화지 그리기

plt.imshow(image)
plt.axis("off")
plt.show()

# %%
import cv2 
import numpy as np 
import matplotlib.pyplot as plt

# 이미지 만들기(h:높이, w:너비, c:채널), RGB 0~255 (255, 255, 255)
image = np.zeros((200,200,3), dtype=np.uint8) + 255 # 화이트 도화지 그리기

# 선 그리기(이미지 - 왼쪽 위 - 오른쪽 아래 - 색상 - 두께 - (옵션))
cv2.line(image, (0,0), (100,100), (0,0,255), 3, lineType=cv2.FILLED)
cv2.line(image, (0,0), (100,100), (0,0,255), 3, lineType=cv2.LINE_AA)

plt.imshow(image)
plt.axis("off")
plt.show()

# %%
import cv2 
import numpy as np 
import matplotlib.pyplot as plt

# 이미지 만들기(h:높이, w:너비, c:채널), RGB 0~255 (255, 255, 255)
image = np.zeros((200,200,3), dtype=np.uint8) + 255 # 화이트 도화지 그리기

# 사각형 그리기1(이미지 - 왼위 점 - 오른쪽아래 점 - 색상, 두께, (옵션))
cv2.rectangle(image, (10,10), (40,40), (255,0,0), 1)
# 사각형 그리기2(이미지 - (시작점x, 시작점y, 너비, 높이) - 색상, 두께, (옵션))
cv2.rectangle(image, (10,10,100,50), (255,0,0), 1)
# 원 그리기(이미지 - 중심점 - 반지름 - 색상 - 두께 - (옵션))
cv2.circle(image, (100,100), 50, (0,0,255), 2)

plt.imshow(image)
plt.axis("off")
plt.show()

# %%
import cv2 
import numpy as np 
import matplotlib.pyplot as plt

# 이미지 만들기(h:높이, w:너비, c:채널), RGB 0~255 (255, 255, 255)
image = np.zeros((200,200,3), dtype=np.uint8) + 255 # 화이트 도화지 그리기
# 텍스트 넣기(이미지 - 텍스트 - 위치 - 폰트 - 크기 - 색상 - 두께)
text = "hello"
cv2.putText(image, text, (0,100), cv2.FONT_HERSHEY_PLAIN, 1, (0,0,255), 2)

plt.imshow(image)
plt.axis("off")
plt.show()

# %%
import cv2 
import numpy as np 
import matplotlib.pyplot as plt
from PIL import ImageFont, ImageDraw, Image

# 이미지 만들기(h:높이, w:너비, c:채널), RGB 0~255 (255, 255, 255)
image = np.zeros((200,200,3), dtype=np.uint8) + 255 # 화이트 도화지 그리기

# 한글 텍스트 넣기 
text = "안녕?"

font_path = "C:/Windows/Fonts/malgun.ttf"
font = ImageFont.truetype(font_path, 20)

image = Image.fromarray(image) # 넘파이배열을 이미지로 바꿈
draw = ImageDraw.Draw(image)   # 이미지에 그림 그릴 준비
draw.text((0,50), text, font=font, fill=(0,0,255)) # 이미지에 텍스트 넣기
text_image = np.array(image) # 이미지를 넘파이배열로 바꿈

plt.imshow(image)
plt.axis("off")
plt.show()

# %% [markdown]
# # 6. 마스크 씌우기

# %%
# starry_night.jpg
# circle.jpg

import cv2 
import matplotlib.pyplot as plt 

image_path1 = "../images/starry_night.jpg"
image_path2 = "../images/circle.jpg"

image1 = cv2.imread(image_path1)
image1 = cv2.cvtColor(image1, cv2.COLOR_BGR2RGB)

image2 = cv2.imread(image_path2)
image2 = cv2.cvtColor(image2, cv2.COLOR_BGR2RGB)

fig, ax = plt.subplots(1, 2, figsize=(10,4))
ax[0].imshow(image1)
ax[0].axis("off")
ax[1].imshow(image2)
ax[1].axis("off")
plt.show()

# %%
import numpy as np 

image_path = "../images/starry_night.jpg"
mask_path = "../images/circle.jpg"

image = cv2.imread(image_path)
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)
# dst = np.zeros(image.shape, dtype=image.dtype)
dst = cv2.imread("../images/starry_night_gray.jpg")

print(image.shape, mask.shape, dst.shape)

# 이미지 합성하기
cv2.copyTo(image, mask, dst)

plt.imshow(dst)
plt.axis("off")
plt.show()
# Out:
# (640, 1024, 3) (640, 1024) (640, 1024, 3)

# %% [markdown]
# # 7. 이미지 처리

# %% [markdown]
# ## 1) 색상 추출

# %%
# 이미지 불러오기
# chocolate.jpg
image = cv2.imread("../images/chocolate.jpg")
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

plt.imshow(image)
plt.axis("off")
plt.show()

# %%
# 색상별로 마스크 추출(이미지 - 색상 하한선 - 색상 상한선)
mask_r = cv2.inRange(image, (128,0,0), (255,128,128))
mask_g = cv2.inRange(image, (0,128,0), (128,255,128))
mask_b = cv2.inRange(image, (0,0,128), (128,128,255))
print(mask_r.shape, mask_g.shape, mask_b.shape)

fig, ax = plt.subplots(1, 4, figsize=(10,4))
ax[0].imshow(image)
ax[0].axis("off")
ax[1].imshow(mask_r, cmap="gray")
ax[1].axis("off")
ax[2].imshow(mask_g, cmap="gray")
ax[2].axis("off")
ax[3].imshow(mask_b, cmap="gray")
ax[3].axis("off")
plt.show()
# Out:
# (152, 200) (152, 200) (152, 200)

# %%
white_dst = np.zeros(image.shape, dtype=np.uint8) + 255
image_red = cv2.copyTo(image, mask_r, white_dst) # white_dst: 하얀색 도화지

white_dst = np.zeros(image.shape, dtype=np.uint8) + 255
image_green = cv2.copyTo(image, mask_g, white_dst)

white_dst = np.zeros(image.shape, dtype=np.uint8) + 255
image_blue = cv2.copyTo(image, mask_b, white_dst)

fig, ax = plt.subplots(1, 4, figsize=(10,4))
ax[0].imshow(image)
ax[0].axis("off")
ax[1].imshow(image_red, cmap="gray")
ax[1].axis("off")
ax[2].imshow(image_green, cmap="gray")
ax[2].axis("off")
ax[3].imshow(image_blue, cmap="gray")
ax[3].axis("off")
plt.show()

# %% [markdown]
# ## 2) 가우시안 블러

# %%
# family.jpg
import cv2 
import matplotlib.pyplot as plt 

image = cv2.imread("../images/family.jpg")
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

sigma = 9 # 3, 5, 7, 9
image_blur = cv2.GaussianBlur(image, (0,0), sigma)

fig, ax = plt.subplots(1, 2, figsize=(5, 4))
ax[0].imshow(image)
ax[0].axis("off")
ax[1].imshow(image_blur)
ax[1].axis("off")
plt.show()

# %% [markdown]
# ## 3) 밝기/대비 조절

# %%
# 밝기 조절: 이미지 전체의 색을 밝게 조정하는 것
# 대비 조절: 밝은 부분과 어두운 부분의 차이를 강조하거나 줄이는 것

# %%
# 밝기 조절
# flowers.jpg

import cv2
import matplotlib.pyplot as plt

image = cv2.imread("../images/flowers.jpg")
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# beta 옵션을 움직여 보세요
image_bright = cv2.convertScaleAbs(image, alpha=1, beta=100)

fig, ax = plt.subplots(1, 2, figsize=(5,4))
ax[0].imshow(image)
ax[0].axis("off")
ax[1].imshow(image_bright)
ax[1].axis("off")
plt.show()

# %%
# 대비 조절
# flowers.jpg

import cv2
import matplotlib.pyplot as plt

image = cv2.imread("../images/flowers.jpg")
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# alpha 옵션을 움직여 보세요
image_contrast = cv2.convertScaleAbs(image, alpha=1.5, beta=1)

fig, ax = plt.subplots(1, 2, figsize=(5,4))
ax[0].imshow(image)
ax[0].axis("off")
ax[1].imshow(image_contrast)
ax[1].axis("off")
plt.show()
